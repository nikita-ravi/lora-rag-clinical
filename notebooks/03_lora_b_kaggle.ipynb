# %% [markdown]
# # LoRA-B Training (Kaggle)
#
# Train LoRA-B (RAFT-style, Q + passages -> reasoned A) on Kaggle 2x T4.
#
# **Instructions:**
# 1. Upload this notebook to Kaggle
# 2. Enable GPU (2x T4)
# 3. Add your HF token and W&B API key to Kaggle secrets
# 4. Run all cells

# %%
# TODO: Implement in M6
